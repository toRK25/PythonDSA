# %%
def mystery(l):
    if l == []:
        return (l)
    else:
        return (l[:-1] + mystery(l[:-1]))

# %%
mystery([23, 35, 19, 58, 93, 46])
# Out:
# [23, 35, 19, 58, 93, 23, 35, 19, 58, 23, 35, 19, 23, 35, 23]
